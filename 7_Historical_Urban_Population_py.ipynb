# %% [markdown]
# ## Historical Urban Population

# %%
import pandas as pd

histurban = pd.read_csv("data/urban/urbanpop.csv")

histurban
# Out:
#        Record       City OtherName Country   Latitude   Longitude  Certainty  \
# 0           1      Eridu       NaN    Iraq  30.815838   45.996070          1
# 1           2      Eridu       NaN    Iraq  30.815838   45.996070          1
# 2           3      Larak      Kesh    Iraq  32.312738   45.660998          1
# 3           4       Uruk     Erech    Iraq  31.322222   45.636111          1
# 4           5     Anshan       NaN    Iran  30.012020   52.408577          1
# ...       ...        ...       ...     ...        ...         ...        ...
# 10347   10348  Zaozhuang       NaN   China  34.866700  117.550000          2
# 10348   10349  Zhanjiang       NaN   China  21.200000  110.400000          1
# 10349   10350  Zhongshan       NaN   China  22.517646  113.392782          1
# 10350   10351   Zhucheng       NaN   China  36.010000  119.416700          1
# 10351   10352       Zibo       NaN   China  36.790560  118.063330          1
#
#        year      pop                cityid
# ...

# %% [markdown]
# ## Some test examples

# %%
histurban.loc[histurban['City'] == 'Cairo']
# Out:
#        Record   City       OtherName Country  Latitude  Longitude  Certainty  \
# 771       772  Cairo  Fostat, Fustat   Egypt  30.06263   31.24967          1
# 827       828  Cairo  Fostat, Fustat   Egypt  30.06263   31.24967          1
# 828       829  Cairo  Fostat, Fustat   Egypt  30.06263   31.24967          1
# 928       929  Cairo  Fostat, Fustat   Egypt  30.06263   31.24967          1
# 945       946  Cairo  Fostat, Fustat   Egypt  30.06263   31.24967          1
# 1026     1027  Cairo  Fostat, Fustat   Egypt  30.06263   31.24967          1
# 1055     1056  Cairo  Fostat, Fustat   Egypt  30.06263   31.24967          1
# 1056     1057  Cairo  Fostat, Fustat   Egypt  30.06263   31.24967          1
# 1173     1174  Cairo  Fostat, Fustat   Egypt  30.06263   31.24967          1
# 1236     1237  Cairo  Fostat, Fustat   Egypt  30.06263   31.24967          1
# 1342     1343  Cairo  Fostat, Fustat   Egypt  30.06263   31.24967          1
# ...

# %%
histurban.loc[histurban['City'] == 'Rome']
# Out:
#        Record  City OtherName Country  Latitude  Longitude  Certainty  year  \
# 369       370  Rome       NaN   Italy  41.89474    12.4839          1  -500
# 394       395  Rome       NaN   Italy  41.89474    12.4839          1  -430
# 417       418  Rome       NaN   Italy  41.89474    12.4839          1  -400
# 436       437  Rome       NaN   Italy  41.89474    12.4839          1  -300
# 472       473  Rome       NaN   Italy  41.89474    12.4839          1  -200
# 519       520  Rome       NaN   Italy  41.89474    12.4839          1  -100
# 544       545  Rome       NaN   Italy  41.89474    12.4839          1     1
# 564       565  Rome       NaN   Italy  41.89474    12.4839          1   100
# 565       566  Rome       NaN   Italy  41.89474    12.4839          1   100
# 584       585  Rome       NaN   Italy  41.89474    12.4839          1   200
# 602       603  Rome       NaN   Italy  41.89474    12.4839          1   300
# ...

# %%
histurban.loc[histurban['City'] == 'London']
# Out:
#        Record    City OtherName         Country   Latitude  Longitude  \
# 506       507  London       NaN  United Kingdom  51.511214  -0.119825
# 1436     1437  London       NaN  United Kingdom  51.511214  -0.119825
# 1515     1516  London       NaN  United Kingdom  51.511214  -0.119825
# 1828     1829  London       NaN  United Kingdom  51.511214  -0.119825
# 1990     1991  London       NaN  United Kingdom  51.511214  -0.119825
# 2105     2106  London       NaN  United Kingdom  51.511214  -0.119825
# 2236     2237  London       NaN  United Kingdom  51.511214  -0.119825
# 2451     2452  London       NaN  United Kingdom  51.511214  -0.119825
# 2690     2691  London       NaN  United Kingdom  51.511214  -0.119825
# 2932     2933  London       NaN  United Kingdom  51.511214  -0.119825
# 3020     3021  London       NaN  United Kingdom  51.511214  -0.119825
# 3180     3181  London       NaN  United Kingdom  51.511214  -0.119825
# ...

# %%
histurban.loc[histurban['City'] == 'Atlanta']
# Out:
#       Record     City OtherName                   Country  Latitude  \
# 7762    7763  Atlanta       NaN  United States of America    33.749
# 8921    8922  Atlanta       NaN  United States of America    33.749
# 9182    9183  Atlanta       NaN  United States of America    33.749
# 9688    9689  Atlanta       NaN  United States of America    33.749
#
#       Longitude  Certainty  year      pop              cityid
# 7762  -84.38798          1  1900    90000  Atlanta_33.7_-84.4
# 8921  -84.38798          1  1925   245000  Atlanta_33.7_-84.4
# 9182  -84.38798          1  1950   507000  Atlanta_33.7_-84.4
# 9688  -84.38798          1  1975  1700000  Atlanta_33.7_-84.4

# %%
histurban.loc[histurban['City'] == 'Beijing']
# Out:
#        Record     City OtherName Country  Latitude  Longitude  Certainty  \
# 941       942  Beijing    Peking   China   39.9075  116.39723          1
# 1013     1014  Beijing    Peking   China   39.9075  116.39723          1
# 1052     1053  Beijing    Peking   China   39.9075  116.39723          1
# 1229     1230  Beijing    Peking   China   39.9075  116.39723          1
# 1318     1319  Beijing    Peking   China   39.9075  116.39723          1
# 1339     1340  Beijing    Peking   China   39.9075  116.39723          1
# 1399     1400  Beijing    Peking   China   39.9075  116.39723          1
# 1452     1453  Beijing    Peking   China   39.9075  116.39723          1
# 1636     1637  Beijing    Peking   China   39.9075  116.39723          1
# 1715     1716  Beijing    Peking   China   39.9075  116.39723          1
# 1717     1718  Beijing    Peking   China   39.9075  116.39723          1
# 1762     1763  Beijing    Peking   China   39.9075  116.39723          1
# ...

# %%
histurban.loc[histurban['City'] == 'Athens']
# Out:
#       Record    City OtherName Country  Latitude  Longitude  Certainty  year  \
# 375      376  Athens       NaN  Greece  37.97945   23.71622          1  -430
# 406      407  Athens       NaN  Greece  37.97945   23.71622          1  -400
# 493      494  Athens       NaN  Greece  37.97945   23.71622          1  -100
# 1758    1759  Athens       NaN  Greece  37.97945   23.71622          1  1300
# 2088    2089  Athens       NaN  Greece  37.97945   23.71622          1  1370
# 2160    2161  Athens       NaN  Greece  37.97945   23.71622          1  1400
# 2601    2602  Athens       NaN  Greece  37.97945   23.71622          1  1500
# 3224    3225  Athens       NaN  Greece  37.97945   23.71622          1  1578
# 3342    3343  Athens       NaN  Greece  37.97945   23.71622          1  1600
# 3910    3911  Athens       NaN  Greece  37.97945   23.71622          1  1664
# 3926    3927  Athens       NaN  Greece  37.97945   23.71622          1  1669
# ...
