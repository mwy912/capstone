# %% [markdown]
# ## Reload the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

meteorites = pd.read_csv("data/meteorites.csv")

meteorites = meteorites.drop('Unnamed: 0', axis=1)

meteorites
# Out:
#             name     id nametype              recclass  mass_in_grams  \
# 0         Aachen      1    Valid                    L5           21.0
# 1         Aarhus      2    Valid                    H6          720.0
# 2           Abee      6    Valid                   EH4       107000.0
# 3       Acapulco     10    Valid           Acapulcoite         1914.0
# 4        Achiras    370    Valid                    L6          780.0
# ...          ...    ...      ...                   ...            ...
# 9776  Zillah 002  31356    Valid               Eucrite          172.0
# 9777      Zinder  30409    Valid  Pallasite, ungrouped           46.0
# 9778        Zlin  30410    Valid                    H4            3.3
# 9779   Zubkovsky  31357    Valid                    L6         2167.0
# 9780  Zulu Queen  30414    Valid                  L3.7          200.0
#
#      fell_or_found    year  latitude  longitude             GeoLocation
# ...

# %% [markdown]
# ## Preliminary Statistical Analysis

# %%
plt.hist(meteorites.mass_in_grams, bins='auto', density=True, facecolor='blue',label='Discrete PDF', alpha=0.25, edgecolor="k")

plt.xlabel("mass_in_grams")
plt.ylabel("Probability Density")
plt.legend(loc='upper right')
