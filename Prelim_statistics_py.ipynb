# %% [markdown]
# ## Reload the data

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

meteorites = pd.read_csv("data/meteorites.csv")

meteorites = meteorites.drop('Unnamed: 0', axis=1) # remove old ID column

meteorites
# Out:
#             name     id nametype              recclass  mass_in_grams  \
# 0         Aachen      1    Valid                    L5           21.0
# 1         Aarhus      2    Valid                    H6          720.0
# 2           Abee      6    Valid                   EH4       107000.0
# 3       Acapulco     10    Valid           Acapulcoite         1914.0
# 4        Achiras    370    Valid                    L6          780.0
# ...          ...    ...      ...                   ...            ...
# 9776  Zillah 002  31356    Valid               Eucrite          172.0
# 9777      Zinder  30409    Valid  Pallasite, ungrouped           46.0
# 9778        Zlin  30410    Valid                    H4            3.3
# 9779   Zubkovsky  31357    Valid                    L6         2167.0
# 9780  Zulu Queen  30414    Valid                  L3.7          200.0
#
#      fell_or_found    year  latitude  longitude             GeoLocation
# ...

# %% [markdown]
# ## Column Prep: Categories

# %%
# Fell or Found:

meteorites['fell_or_found'] = pd.Categorical(meteorites['fell_or_found'])

# Size:

size = []
for row in meteorites['mass_in_grams']:
        if   row <   100: size.append('tiny')
        elif row <  1000: size.append('small')
        elif row <  5000: size.append('medium')
        elif row < 10000: size.append('large')
        else:             size.append('huge')
meteorites['size'] = size
meteorites['size']= pd.Categorical(meteorites['size'])

# Recclass

meteorites['recclass']= pd.Categorical(meteorites['recclass'])

# %% [markdown]
# ## Visualization and charts

# %%
fall_pie = meteorites['fell_or_found'].value_counts()

print(fall_pie)
plot = fall_pie.plot.pie(figsize=(5, 5))
# Out:
# Found    8686
# Fell     1095
# Name: fell_or_found, dtype: int64

# %%
size_pie = meteorites['size'].value_counts()
print (size_pie)
plot = size_pie.plot.pie(figsize=(5, 5))
# Out:
# small     3937
# tiny      2533
# medium    1651
# huge      1202
# large      458
# Name: size, dtype: int64

# %%
recclass_pie = meteorites['recclass'].value_counts()

plot = recclass_pie.plot.pie(figsize=(20,20))

# %%
recclass_pie = meteorites['recclass'].value_counts()

plot = recclass_pie.plot.barh(figsize=(20,100))

# %%
pd.set_option('display.max_rows', None)

recclass_pie.to_frame()
# Out:
#                          recclass
# L6                           1800
# H5                           1662
# H6                            884
# H4                            811
# L5                            680
# L4                            323
# LL6                           230
# Iron, IIIAB                   230
# H5/6                          127
# H4/5                          113
# LL5                           102
# H~5                            89
# Iron                           78
# Iron, IIAB                     77
# L~6                            75
# Iron, ungrouped                75
# H3                             71
# Ureilite                       70
# OC                             66
# Iron, IAB-MG                   66
# CO3                            66
# Iron, IVA                      60
# L5/6                           54
# Mesosiderite                   53
# Lunar (anorth)                 47
# Stone-uncl                     45
# ...
